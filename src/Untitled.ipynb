# %%
import pandas as pd
import afinn
import seaborn as sns

# %% [markdown]
# ## Data preparation

# %%
cols = ['date','afinn_sentiment','pnn_sentiment','price_percent_change','volume_percent_change','next_day_price_percent_change_shifted']

# %%
df = pd.read_csv("../data/model_data/csv/Apple.csv/part-00000-6aac7173-ccb5-4be8-9f64-e07dcc57e4a7-c000.csv",names=cols)

# %%
'posi','neg','net'
1,-1,0
# Out:
# (1, -1, 0)

# %%
df.head()
# Out:
#          date  afinn_sentiment  pnn_sentiment  price_percent_change  \
# 0  2017-01-04         0.863536       0.878788             -0.111917
# 1  2017-01-05         1.282220       0.948718              0.508567
# 2  2017-01-06         0.977553       0.857143              1.114799
# 3  2017-01-09         1.207880       0.863636              0.915943
# 4  2017-01-10         1.334555       1.000000              0.100867
#
#    volume_percent_change  next_day_price_percent_change_shifted
# 0             -26.627151                               0.508567
# 1               5.092788                               1.114799
# 2              43.067820                               0.915943
# 3               5.700446                               0.100867
# 4             -27.113483                               0.537323

# %%
afinn.Afinn().score("good day")
# Out:
# 3.0

# %% [markdown]
# ## EDA

# %%
corr = df.iloc[:,1:].corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (1830, 6)

# %% [markdown]
# ### LSTM, with and without sentiment

# %% [markdown]
# ### Classical ML models

# %%
aff
