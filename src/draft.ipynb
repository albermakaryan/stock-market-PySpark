# %%
from utils.get_news import get_stock_news

# %%
stock = 'Bitcoin'

# %%
 "11 May 2022"

# %%
result = get_stock_news(stock,start_year=2021,start_day=13,start_month=4)
# Out:
# Start date: 2021-04-13 00:00:00, End date: 2021-04-15 00:00:00
# Number of articles: 100
# Required date range:  2021-04-13 00:00:00 2021-04-15 00:00:00
# Actual date:  Tue, 13 Apr 2021 07:00:00 GMT
# Required date range:  2021-04-13 00:00:00 2021-04-15 00:00:00
# Actual date:  Thu, 15 Apr 2021 07:00:00 GMT
# An error occurred while fetching the article: Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/turkey-bans-use-cryptocurrencies-payments-sends-bitcoin-down-2021-04-16/ on URL https://news.google.com/rss/articles/CBMia2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL3RlY2hub2xvZ3kvdHVya2V5LWJhbnMtdXNlLWNyeXB0b2N1cnJlbmNpZXMtcGF5bWVudHMtc2VuZHMtYml0Y29pbi1kb3duLTIwMjEtMDQtMTYv0gEA?oc=5&hl=en-US&gl=US&ceid=US:en
# Required date range:  2021-04-13 00:00:00 2021-04-15 00:00:00
# Actual date:  Tue, 13 Apr 2021 07:00:00 GMT
# Required date range:  2021-04-13 00:00:00 2021-04-15 00:00:00
# Actual date:  Wed, 14 Apr 2021 07:00:00 GMT
# ...
