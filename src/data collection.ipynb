# %%
from utils.get_news import get_stock_news

# %%
stocks = ['Tesla','Google','Apple','Bitcoin','NVIDIA']
for stock in stocks:
    result = get_stock_news(stock,start_year=2017)
    break
    # break
# Out:
# Start date: 2017-01-01 00:00:00, End date: 2017-01-03 00:00:00
# Number of articles: 34
# Required date range:  2017-01-01 00:00:00 2017-01-03 00:00:00
# Actual date:  Tue, 03 Jan 2017 08:00:00 GMT
# Required date range:  2017-01-01 00:00:00 2017-01-03 00:00:00
# Actual date:  Tue, 03 Jan 2017 08:00:00 GMT
# Required date range:  2017-01-01 00:00:00 2017-01-03 00:00:00
# Actual date:  Tue, 03 Jan 2017 08:00:00 GMT
# Required date range:  2017-01-01 00:00:00 2017-01-03 00:00:00
# Actual date:  Tue, 03 Jan 2017 08:00:00 GMT
# Required date range:  2017-01-01 00:00:00 2017-01-03 00:00:00
# Actual date:  Tue, 03 Jan 2017 08:00:00 GMT
# ...

# %%
get_stock_news?
# Out:
# Signature:
# get_stock_news(
#     stock: str,
#     dir_to_save=None,
#     end_date='today',
#     start_year=2018,
#     start_month=1,
#     start_day=1,
#     end_year=2024,
#     end_month=12,
#     end_day=31,
#     day_range=2,
# )
# Docstring: <no docstring>
# File:      ~/Desktop/SJSU_Spring_2024/BigData/stock-market-PySpark/src/utils/get_news.py
# Type:      function

# %%
result.keys()
# Out:
# dict_keys(['title', 'description', 'published date', 'url', 'publisher', 'article', 'publisher_url'])

# %%
result['published date']
# Out:
# 'Tue, 02 Jan 2018 08:00:00 GMT'
